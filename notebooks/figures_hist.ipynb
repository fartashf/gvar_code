# %%
import torch
from torch.autograd import Variable
import numpy as np
import pylab as plt
# %matplotlib inline
import torchvision.utils as vutils
import glob
import tensorflow as tf

# %%
import sys
sys.path.append('../')
import models
import models.mnist
from data import get_loaders
from main import DictWrapper

# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport log_plotter
from log_plotter import get_run_names, get_data, get_data_pth, plot_smooth, plot_tag, plot_runs_and_tags

# %% [markdown]
# # MNIST

# %% [markdown]
# ## tuning lr

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_hist/.*sgd']  # (?!.*scheduler)
tag_names = ['Tacc', 'Vacc', 'Tloss', 'touch_p',]  #  'bumped_p', 'epoch', 'tau', 'alpha_normed_h_log_1', 'alpha_normed_h_log_50', 'alpha_normed_h_log_100'  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100', 'grad_var', 'grad_var_n']
fig_name = 'figs_hist/mnist_hist.png'
lg_tags = ['sgd', 'tau', 'lr']
ylim = [[98, 100], [97,100], [1e-4, 1e-1], [0, 100], [0, 20], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = False
ncolor = 4
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor)

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_hist/.*adam']  # (?!.*scheduler)
tag_names = ['Tacc', 'Vacc', 'Tloss', 'touch_p',]  #  'bumped_p', 'epoch', 'tau', 'alpha_normed_h_log_1', 'alpha_normed_h_log_50', 'alpha_normed_h_log_100'  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100', 'grad_var', 'grad_var_n']
fig_name = 'figs_hist/mnist_hist.png'
lg_tags = ['sgd', 'tau', 'lr']
ylim = [[98, 100], [97,100], [1e-4, 1e-1], [0, 100], [0, 20], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = False
ncolor = 4
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor)

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_hist/.*scheduler']  # (?!.*scheduler)
tag_names = ['Tacc', 'Vacc', 'Tloss', 'touch_p',]  #  'bumped_p', 'epoch', 'tau', 'alpha_normed_h_log_1', 'alpha_normed_h_log_50', 'alpha_normed_h_log_100'  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100', 'grad_var', 'grad_var_n']
fig_name = 'figs_hist/mnist_hist.png'
lg_tags = ['sgd,', 'adam,', 'lr']
ylim = [[98, 100], [97,100], [1e-4, 1e-1], [0, 100], [0, 20], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = False
ncolor = 4
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor)

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_hist/(?!.*scheduler)']  # (?!.*scheduler)
tag_names = ['Tacc', 'Vacc', 'Tloss', 'touch_p',]  #  'bumped_p', 'epoch', 'tau', 'alpha_normed_h_log_1', 'alpha_normed_h_log_50', 'alpha_normed_h_log_100'  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100', 'grad_var', 'grad_var_n']
fig_name = 'figs_hist/mnist_hist.png'
lg_tags = ['sgd', 'adam', 'lr']
ylim = [[98, 100], [97,100], [1e-4, 1e-1], [0, 100], [0, 20], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = False
ncolor = 4
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor)

# %% [markdown]
# evaluated by the final training loss, the best lr for adam matches the best lr for sgd. both for ours and vanilla.

# %% [markdown]
# ## sgd vs adam histo

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_hist/(.*lr_0.02.*sgd|.*lr_0.05.*adam)(?!.*scheduler)']  # (?!.*scheduler)
tag_names = ['Tacc', 'Vacc', 'Tloss', 'touch_p'  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100']  #  'bumped_p', 'epoch', 'tau', 'alpha_normed_h_log_1', 'alpha_normed_h_log_50', 'alpha_normed_h_log_100'  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100', 'grad_var', 'grad_var_n']
fig_name = 'figs_hist/mnist_hist.png'
lg_tags = ['tau', 'sgd', 'adam']
ylim = [[98, 100], [97,100], [1e-4, 1e-1], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = False
ncolor = None
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor)

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_hist/(.*lr_0.02.*sgd|.*lr_0.05.*adam)(.*scheduler)']  # (?!.*scheduler)
tag_names = ['Tacc', 'Vacc', 'Tloss', 'touch_p'  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100']  #  'bumped_p', 'epoch', 'tau', 'alpha_normed_h_log_1', 'alpha_normed_h_log_50', 'alpha_normed_h_log_100'  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100', 'grad_var', 'grad_var_n']
fig_name = 'figs_hist/mnist_hist.png'
lg_tags = ['tau', 'sgd', 'adam']
ylim = [[98, 100], [97,100], [1e-4, 1e-1], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = False
ncolor = None
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor)

# %% [markdown]
# shape is the same for adam and sgd, adam doing better at the beginning. matches the loss curve

# %% [markdown]
# # SSMLP

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_hist/.*ssmlp']  # (?!.*scheduler)
tag_names = ['Tacc', 'Vacc', 'Tloss', 'touch_p', 'tauloss_mu', 'tauloss_std', 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100', 'grad_var', 'grad_var_n']  #  'bumped_p', 'epoch', 'tau', 'alpha_normed_h_log_1', 'alpha_normed_h_log_50', 'alpha_normed_h_log_100'  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100']
fig_name = 'figs_hist/mnist_hist.png'
lg_tags = ['tau', 'sgd', 'params_']
ylim = [None, None, None, [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = None
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor)

# %% [markdown]
# * super small model on mnist is not exactly the same story as imagenet. higher thresholds still perform better than vanilla sgd. it's just that a peak appears right in the middle.
# * main thing to note, there are still two modes, the lower mode is just shifted up.

# %% [markdown]
# # Imagenet

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_imagenet_hist/.*sgd']
tag_names = ['Tloss', 'Vloss', 'Tacc', 'Vacc', 'touch_p', 'bumped_p', 'epoch', 'tau', 'tauloss_mu', 'tauloss_std', 'alpha_normed_h_log_1', 'alpha_normed_h_log_50', 'alpha_normed_h_log_100', 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100', 'grad_var', 'grad_var_n']  # , 'visits_h', 'count_h']  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100'
fig_name = 'figs_expsnooze/imagenet_hist.png'
# lg_tags = ['sgd', 'w2c_', 'params_'] # params_0.1|.*params_0.001
lg_tags = ['sgd', 'adam', 'tau', 'params_']  # 'w2c_', , 'params_.......', '/.._', 
ylim = [None, None, None, None, [0, 100], [0, 20], None, [np.exp(-1), np.exp(2)], None, None, None, None, None, None, None, None, None, [1.1, 1.3]]
sep_h = False
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h)
