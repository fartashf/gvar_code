# %%
import torch
from torch.autograd import Variable
import numpy as np
import pylab as plt
# %matplotlib inline
import torchvision.utils as vutils
import glob
import tensorflow as tf
import matplotlib.gridspec as gridspec
from torchvision import datasets, transforms

# %%
# %load_ext autoreload
# %autoreload 1

# %%
import sys
sys.path.append('../')
# %aimport log_plotter
from log_plotter import plot_clusters

# %%
run_dir = '../runs/mnist/'
gfname = 'bgluster_train_test'
images=plot_clusters(run_dir, gfname, nsamples=20)
# Out:
# Train loss: 0.1138
# Train accuracy: 96.87%
#
# Cluster 7, size: 57816
# Cluster 7, normC: 0.00006830
# Cluster 7, loss: 0.0562
# Cluster 7, accuracy: 98.78%
#
# Cluster 8, size: 665
# Cluster 8, normC: 0.00322048
# Cluster 8, loss: 0.7562
# Cluster 8, accuracy: 75.34%
#
# Cluster 5, size: 239
# Cluster 5, normC: 0.00401793
# Cluster 5, loss: 1.1091
# Cluster 5, accuracy: 56.07%
#
# Cluster 2, size: 270
# Cluster 2, normC: 0.00514098
# Cluster 2, loss: 1.3017
# Cluster 2, accuracy: 50.74%
#
# Cluster 3, size: 403
# Cluster 3, normC: 0.00494605
# Cluster 3, loss: 1.5195
# Cluster 3, accuracy: 46.65%
#
# Cluster 0, size: 164
# Cluster 0, normC: 0.00971394
# Cluster 0, loss: 1.9377
# Cluster 0, accuracy: 21.95%
#
# Cluster 1, size: 86
# Cluster 1, normC: 0.01204972
# Cluster 1, loss: 2.9796
# Cluster 1, accuracy: 6.98%
#
# Cluster 4, size: 135
# Cluster 4, normC: 0.01127105
# Cluster 4, loss: 3.0886
# Cluster 4, accuracy: 4.44%
#
# Cluster 6, size: 67
# Cluster 6, normC: 0.01541440
# ...

# %%
run_dir = '../runs/mnist/'
gfname = 'bgluster_test'
images=plot_clusters(run_dir, gfname, nsamples=20)
# Out:
# Train loss: 0.1268
# Train accuracy: 96.50%
#
# Cluster 9, size: 9489
# Cluster 9, normC: 0.00004870
# Cluster 9, loss: 0.0510
# Cluster 9, accuracy: 98.94%
#
# Cluster 4, size: 150
# Cluster 4, normC: 0.00339302
# Cluster 4, loss: 1.0582
# Cluster 4, accuracy: 68.67%
#
# Cluster 3, size: 94
# Cluster 3, normC: 0.00420436
# Cluster 3, loss: 1.1732
# Cluster 3, accuracy: 58.51%
#
# Cluster 6, size: 49
# Cluster 6, normC: 0.00750532
# Cluster 6, loss: 1.2734
# Cluster 6, accuracy: 44.90%
#
# Cluster 1, size: 66
# Cluster 1, normC: 0.00582300
# Cluster 1, loss: 1.4524
# Cluster 1, accuracy: 48.48%
#
# Cluster 5, size: 42
# Cluster 5, normC: 0.00628549
# Cluster 5, loss: 1.5099
# Cluster 5, accuracy: 42.86%
#
# Cluster 7, size: 39
# Cluster 7, normC: 0.00511778
# Cluster 7, loss: 1.6276
# Cluster 7, accuracy: 48.72%
#
# Cluster 8, size: 34
# Cluster 8, normC: 0.00897273
# Cluster 8, loss: 1.8054
# Cluster 8, accuracy: 35.29%
#
# Cluster 0, size: 21
# Cluster 0, normC: 0.01780035
# ...

# %%
run_dir = '../runs/resnet34/'
gfname = 'bgluster_test'
images=plot_clusters(run_dir, gfname, nsamples=50, sz=48)
# Out:
# Total loss: 1.0989
# Total accuracy: 91.11%
# Total dist: -12.8902
#
# Cluster 19, size: 34507
# Cluster 19, normC: 0.01329814
# Cluster 19, loss: 0.2379
# Cluster 19, accuracy: 99.40%
#
# Cluster 10, size: 1937
# Cluster 10, normC: 0.34636357
# Cluster 10, loss: 1.6236
# Cluster 10, accuracy: 88.49%
#
# Cluster 16, size: 1989
# Cluster 16, normC: 0.38923833
# Cluster 16, loss: 1.6300
# Cluster 16, accuracy: 89.69%
#
# Cluster 15, size: 709
# Cluster 15, normC: 0.67937428
# Cluster 15, loss: 2.8371
# Cluster 15, accuracy: 74.05%
#
# Cluster 17, size: 1100
# Cluster 17, normC: 0.58914524
# Cluster 17, loss: 2.9899
# Cluster 17, accuracy: 74.64%
#
# Cluster 12, size: 714
# Cluster 12, normC: 0.71189064
# Cluster 12, loss: 3.1220
# Cluster 12, accuracy: 70.45%
#
# Cluster 14, size: 881
# Cluster 14, normC: 0.61068928
# Cluster 14, loss: 3.1282
# Cluster 14, accuracy: 72.99%
#
# Cluster 8, size: 970
# Cluster 8, normC: 0.66117275
# Cluster 8, loss: 3.1782
# Cluster 8, accuracy: 74.43%
#
# ...

# %%
run_dir = '../runs/resnet34_seed2/'
gfname = 'bgluster_test'
images=plot_clusters(run_dir, gfname, nsamples=50, sz=48)
# Out:
# Total loss: 1.0989
# Total accuracy: 91.11%
# Total dist: -12.7177
#
# Cluster 1, size: 34372
# Cluster 1, normC: 0.01345113
# Cluster 1, loss: 0.2329
# Cluster 1, accuracy: 99.41%
#
# Cluster 3, size: 2764
# Cluster 3, normC: 0.34257200
# Cluster 3, loss: 1.3928
# Cluster 3, accuracy: 91.61%
#
# Cluster 14, size: 1454
# Cluster 14, normC: 0.46091092
# Cluster 14, loss: 2.2704
# Cluster 14, accuracy: 84.94%
#
# Cluster 5, size: 1121
# Cluster 5, normC: 0.51564366
# Cluster 5, loss: 2.6912
# Cluster 5, accuracy: 75.83%
#
# Cluster 4, size: 720
# Cluster 4, normC: 0.62163579
# Cluster 4, loss: 2.9843
# Cluster 4, accuracy: 73.47%
#
# Cluster 19, size: 867
# Cluster 19, normC: 0.64393210
# Cluster 19, loss: 2.9942
# Cluster 19, accuracy: 73.93%
#
# Cluster 18, size: 989
# Cluster 18, normC: 0.51853281
# Cluster 18, loss: 3.0697
# Cluster 18, accuracy: 72.80%
#
# Cluster 6, size: 644
# Cluster 6, normC: 0.71939659
# Cluster 6, loss: 3.1474
# Cluster 6, accuracy: 71.43%
#
# ...

# %%
run_dir = '../runs/resnet34_fc/'
gfname = 'bgluster_test'
images=plot_clusters(run_dir, gfname, nsamples=50, sz=48)
# Out:
# Total loss: 1.0989
# Total accuracy: 91.11%
# Total dist: -0.1524
#
# Cluster 1, size: 42019
# Cluster 1, normC: 0.00054396
# Cluster 1, loss: 0.7130
# Cluster 1, accuracy: 94.77%
#
# Cluster 6, size: 23
# Cluster 6, normC: 0.29255074
# Cluster 6, loss: 1.8970
# Cluster 6, accuracy: 91.30%
#
# Cluster 7, size: 461
# Cluster 7, normC: 0.02016817
# Cluster 7, loss: 2.8289
# Cluster 7, accuracy: 78.09%
#
# Cluster 0, size: 531
# Cluster 0, normC: 0.01682255
# Cluster 0, loss: 2.8611
# Cluster 0, accuracy: 77.59%
#
# Cluster 5, size: 497
# Cluster 5, normC: 0.01935781
# Cluster 5, loss: 2.9066
# Cluster 5, accuracy: 75.86%
#
# Cluster 8, size: 463
# Cluster 8, normC: 0.01860709
# Cluster 8, loss: 2.9240
# Cluster 8, accuracy: 75.59%
#
# Cluster 13, size: 513
# Cluster 13, normC: 0.01813476
# Cluster 13, loss: 3.0218
# Cluster 13, accuracy: 71.93%
#
# Cluster 14, size: 431
# Cluster 14, normC: 0.02046700
# Cluster 14, loss: 3.0297
# Cluster 14, accuracy: 73.55%
#
# Cluster 10, size: 501
# ...

# %%
run_dir = '../runs/resnet34_act/'
gfname = 'bgluster_test'
images=plot_clusters(run_dir, gfname, nsamples=50, sz=48)
# Out:
# Total loss: 1.0989
# Total accuracy: 91.11%
# Total dist: -10820437.0000
#
# Cluster 1, size: 2871
# Cluster 1, normC: 749.79302979
# Cluster 1, loss: 0.3799
# Cluster 1, accuracy: 97.49%
#
# Cluster 15, size: 2889
# Cluster 15, normC: 739.20446777
# Cluster 15, loss: 0.7356
# Cluster 15, accuracy: 95.74%
#
# Cluster 4, size: 1850
# Cluster 4, normC: 746.94641113
# Cluster 4, loss: 0.8200
# Cluster 4, accuracy: 93.62%
#
# Cluster 6, size: 3741
# Cluster 6, normC: 716.63000488
# Cluster 6, loss: 0.8404
# Cluster 6, accuracy: 94.33%
#
# Cluster 17, size: 2121
# Cluster 17, normC: 731.26147461
# Cluster 17, loss: 0.8513
# Cluster 17, accuracy: 93.49%
#
# Cluster 3, size: 5813
# Cluster 3, normC: 720.31280518
# Cluster 3, loss: 0.9131
# Cluster 3, accuracy: 94.36%
#
# Cluster 9, size: 1376
# Cluster 9, normC: 678.58868408
# Cluster 9, loss: 0.9835
# Cluster 9, accuracy: 92.30%
#
# Cluster 19, size: 2718
# Cluster 19, normC: 754.99517822
# Cluster 19, loss: 1.0210
# ...

# %%
run_dir = '../runs/alexnet/'
gfname = 'bgluster_test'
images=plot_clusters(run_dir, gfname, nsamples=50, sz=48)
# Out:
# Total loss: 1.9476
# Total accuracy: 78.62%
# Total dist: -0.2432
#
# Cluster 3, size: 29564
# Cluster 3, normC: 0.00539853
# Cluster 3, loss: 0.6647
# Cluster 3, accuracy: 95.69%
#
# Cluster 8, size: 1649
# Cluster 8, normC: 0.08979122
# Cluster 8, loss: 2.7729
# Cluster 8, accuracy: 69.98%
#
# Cluster 7, size: 2044
# Cluster 7, normC: 0.08513661
# Cluster 7, loss: 3.0568
# Cluster 7, accuracy: 63.99%
#
# Cluster 18, size: 1790
# Cluster 18, normC: 0.08399560
# Cluster 18, loss: 3.3268
# Cluster 18, accuracy: 60.00%
#
# Cluster 9, size: 1323
# Cluster 9, normC: 0.10473450
# Cluster 9, loss: 3.5239
# Cluster 9, accuracy: 57.97%
#
# Cluster 6, size: 944
# Cluster 6, normC: 0.11104545
# Cluster 6, loss: 3.5528
# Cluster 6, accuracy: 57.10%
#
# Cluster 0, size: 1447
# Cluster 0, normC: 0.09015848
# Cluster 0, loss: 3.6160
# Cluster 0, accuracy: 58.26%
#
# Cluster 2, size: 1198
# Cluster 2, normC: 0.09349671
# Cluster 2, loss: 3.6890
# Cluster 2, accuracy: 57.10%
#
# ...

# %%
run_dir = '../runs/resnet34_input0/'
gfname = 'bgluster_test'
images=plot_clusters(run_dir, gfname, nsamples=50, sz=48)
# Out:
# Total loss: 1.0989
# Total accuracy: 91.11%
# Total dist: -14240018.0000
#
# Cluster 11, size: 1384
# Cluster 11, normC: 507.77072144
# Cluster 11, loss: 0.7919
# Cluster 11, accuracy: 94.29%
#
# Cluster 19, size: 476
# Cluster 19, normC: 1073.20812988
# Cluster 19, loss: 0.8350
# Cluster 19, accuracy: 95.17%
#
# Cluster 17, size: 534
# Cluster 17, normC: 1018.71862793
# Cluster 17, loss: 0.8937
# Cluster 17, accuracy: 91.95%
#
# Cluster 1, size: 1312
# Cluster 1, normC: 524.44537354
# Cluster 1, loss: 0.9317
# Cluster 1, accuracy: 93.22%
#
# Cluster 16, size: 4587
# Cluster 16, normC: 111.01138306
# Cluster 16, loss: 1.0097
# Cluster 16, accuracy: 92.39%
#
# Cluster 3, size: 3104
# Cluster 3, normC: 914.76550293
# Cluster 3, loss: 1.0604
# Cluster 3, accuracy: 91.33%
#
# Cluster 18, size: 1642
# Cluster 18, normC: 1694.81518555
# Cluster 18, loss: 1.0729
# Cluster 18, accuracy: 91.53%
#
# Cluster 15, size: 639
# Cluster 15, normC: 829.05291748
# Cluster 15, loss: 1.0794
# ...

# %% [markdown]
# ## running

# %%
run_dir = '../runs/resnet34_online/'
gfname = 'bgluster_test'
images=plot_clusters(run_dir, gfname, nsamples=50, sz=48)
# Out:
# Total loss: 1.0989
# Total accuracy: 91.11%
# Total dist: -1.1885
#
# Cluster 15, size: 42456
# Cluster 15, normC: 0.00244534
# Cluster 15, loss: 0.7624
# Cluster 15, accuracy: 93.94%
#
# Cluster 10, size: 45
# Cluster 10, normC: 0.27143899
# Cluster 10, loss: 1.5854
# Cluster 10, accuracy: 95.56%
#
# Cluster 2, size: 21
# Cluster 2, normC: 0.27410817
# Cluster 2, loss: 1.6097
# Cluster 2, accuracy: 95.24%
#
# Cluster 19, size: 39
# Cluster 19, normC: 0.25739655
# Cluster 19, loss: 1.6950
# Cluster 19, accuracy: 97.44%
#
# Cluster 1, size: 21
# Cluster 1, normC: 0.22579871
# Cluster 1, loss: 2.1437
# Cluster 1, accuracy: 80.95%
#
# Cluster 5, size: 15
# Cluster 5, normC: 0.31977564
# Cluster 5, loss: 2.2377
# Cluster 5, accuracy: 80.00%
#
# Cluster 3, size: 20
# Cluster 3, normC: 0.24744807
# Cluster 3, loss: 2.3592
# Cluster 3, accuracy: 75.00%
#
# Cluster 11, size: 30
# Cluster 11, normC: 0.18016291
# Cluster 11, loss: 2.3933
# Cluster 11, accuracy: 80.00%
#
# Cluster 8, size: 22
# ...
