# %%
import torch
from torch.autograd import Variable
import numpy as np
import pylab as plt
# %matplotlib inline
import torchvision.utils as vutils
import glob
import tensorflow as tf

# %%
import sys
sys.path.append('../')
import models
import models.mnist
from data import get_loaders
from main import DictWrapper

# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport log_plotter
from log_plotter import get_run_names, get_data, get_data_pth, plot_smooth, plot_tag, plot_runs_and_tags, get_legend

# %% [markdown]
# # MNIST

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_diff/(00_|.*params_0.01)']  # (?!.*scheduler)
tag_names = ['Tloss', 'Vloss', 'Tacc', 'Vacc', 'touch_p', 'bumped_p', 'alpha_normed_h_log', 'Tloss_h_log_100',] # 'grad_var', 'grad_var_n', 'snoozeC_h']  #  'bumped_p', 'epoch', 'tau', 'alpha_normed_h_log_1', 'alpha_normed_h_log_50', 'alpha_normed_h_log_100'  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100', 'grad_var', 'grad_var_n']
fig_name = 'figs_diff/mnist.png'
lg_tags = ['dmom_']
ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = False
ncolor = None
save_single = False
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, save_single=save_single)

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_diff/(00_|.*dmom_0.0.*params_0.01)']  # (?!.*scheduler)
tag_names = ['Tloss', 'Vloss', 'Tacc', 'Vacc', 'touch_p', 'bumped_p', 'alpha_normed_h_log', 'Tloss_h_log_100',] # 'grad_var', 'grad_var_n', 'snoozeC_h']  #  'bumped_p', 'epoch', 'tau', 'alpha_normed_h_log_1', 'alpha_normed_h_log_50', 'alpha_normed_h_log_100'  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100', 'grad_var', 'grad_var_n']
fig_name = 'figs_diff/mnist.png'
lg_tags = ['diff_']
ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = False
ncolor = None
save_single = False
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, save_single=save_single)

# %% [markdown]
# wait, doesn't have a meaningful difference with dL.

# %% [markdown]
# # Imagenet

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_imagenet_diff/(.*diff_|(?!.*dmom))']
tag_names = ['Tloss', 'Vloss', 'Tacc', 'Vacc', 'touch_p', 'bumped_p', 'epoch', 'tau', 'tauloss_mu', 'tauloss_std', 'alpha_normed_h_log_1', 'alpha_normed_h_log_50', 'alpha_normed_h_log_100', 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100', 'grad_var', 'grad_var_n']  # , 'visits_h', 'count_h']  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100'
fig_name = 'figs_diff/imagenet.png'
# lg_tags = ['sgd', 'w2c_', 'params_'] # params_0.1|.*params_0.001
lg_tags = ['diff_', 'dmom_']  # 'w2c_', , 'params_.......', '/.._', 
ylim = [None]*20
# ylim = [None, None, None, None, [0, 100], [0, 20], None, [np.exp(-1), np.exp(2)], None, None, None, None, None, None, None, None, None, [1.1, 1.3]]
sep_h = False
ncolor = None
save_single = False
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, save_single=save_single)

# %% [markdown]
# dmom=0 looks promising, first time on imagenet I can drop 40% without losing accuracy. nor test accuracy.

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_imagenet_diff/(?!.*dmom_0.(5|9))']
tag_names = ['Tloss', 'Vloss', 'Tacc', 'Vacc', 'touch_p', 'bumped_p', 'epoch', 'tau', 'tauloss_mu', 'tauloss_std', 'alpha_normed_h_log_1', 'alpha_normed_h_log_50', 'alpha_normed_h_log_100', 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100', 'grad_var', 'grad_var_n']  # , 'visits_h', 'count_h']  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100'
fig_name = 'figs_diff/imagenet.png'
# lg_tags = ['sgd', 'w2c_', 'params_'] # params_0.1|.*params_0.001
lg_tags = ['dmom_', 'diff_']  # 'w2c_', , 'params_.......', '/.._', 
ylim = [None]*20
# ylim = [None, None, None, None, [0, 100], [0, 20], None, [np.exp(-1), np.exp(2)], None, None, None, None, None, None, None, None, None, [1.1, 1.3]]
sep_h = False
ncolor = None
save_single = False
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, save_single=save_single)

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_imagenet_diff/(?!.*dmom_0.(5|9))']
tag_names = ['alpha_normed_h_log_20']  # , 'visits_h', 'count_h']  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100'
fig_name = 'figs_diff/imagenet.png'
# lg_tags = ['sgd', 'w2c_', 'params_'] # params_0.1|.*params_0.001
lg_tags = ['dmom_', 'diff_']  # 'w2c_', , 'params_.......', '/.._', 
ylim = [None]*20
# ylim = [None, None, None, None, [0, 100], [0, 20], None, [np.exp(-1), np.exp(2)], None, None, None, None, None, None, None, None, None, [1.1, 1.3]]
sep_h = False
ncolor = None
save_single = False
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, save_single=save_single)

# %% [markdown]
# the loss is not truly bimodal as in the "full training loss" plot. the figures of alpha are bimodal because we drop points and do not update them.
