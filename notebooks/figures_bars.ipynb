# %%
import torch
from torch.autograd import Variable
import numpy as np
import pylab as plt
# %matplotlib inline
import torchvision.utils as vutils
import glob
import tensorflow as tf

# %%
import sys
sys.path.append('../')
import models
import models.mnist
from data import get_loaders
from main import DictWrapper

# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport log_plotter
from log_plotter import get_run_names, get_data, get_data_pth, plot_smooth, plot_tag, plot_runs_and_tags

# %% [markdown]
# # MNIST

# %% [markdown]
# ## sgd

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_bars/']  # (?!.*scheduler)
tag_names = ['Tloss', 'Vloss', 'Tacc', 'Vacc', 'touch_p', 'bumped_p', 'Tloss_h_log_100', 'grad_var', 'grad_var_n', 'snoozeC_h']  #  'bumped_p', 'epoch', 'tau', 'alpha_normed_h_log_1', 'alpha_normed_h_log_50', 'alpha_normed_h_log_100'  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100', 'grad_var', 'grad_var_n']
fig_name = 'figs_bars/mnist.png'
lg_tags = ['sgd', 'adam', 'linrank', 'tau']
ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = False
ncolor = None
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor)

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_bars/']  # (?!.*scheduler)
tag_names = ['snoozeC_h']  #  'bumped_p', 'epoch', 'tau', 'alpha_normed_h_log_1', 'alpha_normed_h_log_50', 'alpha_normed_h_log_100'  , 'Tloss_h_log_1', 'Tloss_h_log_50', 'Tloss_h_log_100', 'grad_var', 'grad_var_n']
fig_name = 'figs_bars/mnist.png'
lg_tags = ['sgd', 'adam', 'linrank', 'tau']
ylim = [[0, 6000], None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = None
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor)

# %% [markdown]
# # CIFAR10

# %% [markdown]
# ![CIFAR10 Wide-resnet results](https://cloud.githubusercontent.com/assets/4953728/20631813/17db5768-b339-11e6-985b-6bbdf4e97aec.png)

# %% [markdown]
# resnet32 is used below, resnet164 above is better, so do not compare

# %%
# get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_wresnet/(.*wrn)']  # (?!.*params_) |.*epoch_60
tag_names = ['Tloss', 'Vloss', 'Terror', 'Verror', 'touch_p', 'bumped_p', 'tau', 'Tloss_h_log_100', 'grad_var', 'grad_var_n', 'lr', 'visits_h', 'snoozeC_h']
fig_name = 'figs_bars/cifar10.png'
# lg_tags = ['sgd', 'w2c_', 'params_'] # params_0.1|.*params_0.001
lg_tags = ['sgd', 'linrank', 'tauXstd', 'exp_lr']  # 'w2c_', , 'params_.......'
ylim = [[1e-4, 1e1], [1e-2, 1e1], [0, 20], [0, 20], [0, 100], [0, 10], None, None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h)

# %%
# get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_wresnet/(.*resnet32)']  # (?!.*params_) |.*epoch_60
tag_names = ['Tloss', 'Vloss', 'Terror', 'Verror', 'touch_p', 'bumped_p', 'tau', 'Tloss_h_log_100', 'grad_var', 'grad_var_n', 'lr', 'visits_h', 'snoozeC_h_10', 'snoozeC_h_50', 'snoozeC_h_70', 'snoozeC_h_100', 'Tloss_h_log_10', 'Tloss_h_log_20']
fig_name = 'figs_bars/cifar10.png'
# lg_tags = ['sgd', 'w2c_', 'params_'] # params_0.1|.*params_0.001
lg_tags = ['sgd', 'linrank', 'tauXstd', 'exp_lr']  # 'w2c_', , 'params_.......'
ylim = [[1e-4, 1e1], [1e-2, 1e1], [0, 20], [0, 20], [0, 100], [0, 10], None, None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h)

# %%
# get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_wresnet/(?!.*params_)']  # (?!.*params_) |.*epoch_60
tag_names = ['Tloss', 'Vloss']
fig_name = 'figs_bars/cifar10.png'
# lg_tags = ['sgd', 'w2c_', 'params_'] # params_0.1|.*params_0.001
lg_tags = ['arch', 'exp_lr']  # 'w2c_', , 'params_.......'
ylim = [[1e-4, 1e1], [1e-2, 1e1], [0, 20], [0, 20], [0, 100], [0, 10], None, None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h)

# %% [markdown]
# on cifar10, wrn28-10 already gets to 100% training accuracy. We can save time until it reaches 100% accuracy. and afterwards sgd does better.

# %%
# get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_wresnet/(.*wrn10-4)']  # (?!.*params_) |.*epoch_60
tag_names = ['Tloss', 'Vloss', 'Terror', 'Verror', 'touch_p', 'bumped_p', 'tau', 'Tloss_h_log_100', 'grad_var', 'grad_var_n', 'lr', 'visits_h', 'snoozeC_h']
fig_name = 'figs_bars/cifar10.png'
# lg_tags = ['sgd', 'w2c_', 'params_'] # params_0.1|.*params_0.001
lg_tags = ['sgd', 'linrank', 'tauXstd', 'exp_lr']  # 'w2c_', , 'params_.......'
ylim = [[1e-4, 1e1], [1e-2, 1e1], [0, 20], [0, 20], [0, 100], [0, 10], None, None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h)

# %% [markdown]
# I tried a much smaller wide-resnet on cifar10. 10 layers deep and widen factor 4.
#
# sgd does not reach 100% training accuracy but ours do. The problem is, we get worse validation performance

# %% [markdown]
# # Alexnet

# %%
# get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_imagenet_small/.*lr_0.0001']  # (?!.*params_) |.*epoch_60
tag_names = ['Tloss', 'Vloss', 'Terror', 'Verror', 'touch_p', 'bumped_p', 'tau', 'Tloss_h_log_100', 'grad_var', 'grad_var_n', 'lr', 'visits_h', 'snoozeC_h']
fig_name = 'figs_bars/imagenet_small.png'
# lg_tags = ['sgd', 'w2c_', 'params_'] # params_0.1|.*params_0.001
lg_tags = ['sgd', 'linrank', 'tauXstd', 'exp_lr']  # 'w2c_', , 'params_.......'
ylim = [[1.5, 2], [1.5, 2.5], [40, 42], [44, 46], [0, 100], [0, 10], None, None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h)

# %%
# get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_imagenet_small/.*lr_1e-05']  # (?!.*params_) |.*epoch_60
tag_names = ['Tloss', 'Vloss', 'Terror', 'Verror', 'touch_p', 'bumped_p', 'tau', 'Tloss_h_log_100', 'grad_var', 'grad_var_n', 'lr', 'visits_h', 'snoozeC_h']
fig_name = 'figs_bars/imagenet_small.png'
# lg_tags = ['sgd', 'w2c_', 'params_'] # params_0.1|.*params_0.001
lg_tags = ['sgd', 'linrank', 'tauXstd', 'exp_lr']  # 'w2c_', , 'params_.......'
ylim = [[1.5, 2], [1.5, 2.5], [40, 42], [44, 46], [0, 100], [0, 10], None, None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h)

# %% [markdown]
# alexnet should get 43.35% validation error. but above it gets 1% more. from [here](https://pytorch.org/docs/stable/torchvision/models.html).

# %% [markdown]
# If the learning rate is not too small, fine-tuning for 20 epochs gives .1% training error decrease but validation gets .2% worse. This is with an adaptive threshold that ends by dropping 40% of data points. dropping more than 40% is bad in terms of training error.
