# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline
x = np.linspace(-3, 3, 100)
y = np.exp(-x**2) + 0.1 * np.random.randn(100)
plt.plot(x, y, 'ro', ms=5)

spl = UnivariateSpline(x, y)
xs = np.linspace(-3, 3, 1000)
plt.plot(xs, spl(xs), 'g', lw=3)

spl.set_smoothing_factor(0.1)
plt.plot(xs, spl(xs), 'b', lw=3)
plt.show()

spl.get_knots()
# Out:
# array([-3.        , -2.87878788, -2.75757576, -2.57575758, -2.51515152,
#        -2.45454545, -2.39393939, -2.21212121, -2.09090909, -2.03030303,
#        -1.90909091, -1.84848485, -1.78787879, -1.72727273, -1.66666667,
#        -1.60606061, -1.54545455, -1.48484848, -1.36363636, -1.24242424,
#        -1.12121212, -1.06060606, -0.87878788, -0.6969697 , -0.63636364,
#        -0.57575758, -0.51515152, -0.39393939, -0.33333333, -0.27272727,
#        -0.21212121, -0.15151515, -0.09090909, -0.03030303,  0.03030303,
#         0.09090909,  0.15151515,  0.27272727,  0.45454545,  0.57575758,
#         0.63636364,  0.6969697 ,  0.75757576,  0.81818182,  0.87878788,
#         0.93939394,  1.        ,  1.06060606,  1.12121212,  1.18181818,
#         1.24242424,  1.3030303 ,  1.36363636,  1.48484848,  1.54545455,
#         1.60606061,  1.66666667,  1.72727273,  1.90909091,  2.03030303,
#         2.09090909,  2.15151515,  2.21212121,  2.27272727,  2.33333333,
#         2.39393939,  2.45454545,  2.51515152,  2.57575758,  2.63636364,
#         2.75757576,  2.81818182,  3.        ])

# %%
from scipy.interpolate import LSQUnivariateSpline, UnivariateSpline
import matplotlib.pyplot as plt
x = np.linspace(-3, 3, 50)
y = np.exp(-x**2) + 0.1 * np.random.randn(50)

# %%
t = [-1, 0, 1]
spl = LSQUnivariateSpline(x, y, t)

# %%
xs = np.linspace(-3, 3, 1000)
plt.plot(x, y, 'ro', ms=5)
plt.plot(xs, spl(xs), 'g-', lw=3)
plt.show()

# %%
nknots = 30
t = np.linspace(-3, 3, nknots+2)[1:-1]
spl = LSQUnivariateSpline(x, y, t)

xs = np.linspace(-3, 3, 1000)
plt.plot(x, y, 'ro', ms=5)
plt.plot(xs, spl(xs), 'g-', lw=3)
plt.show()

spl.get_knots()
# Out:
# array([-3.        , -2.80645161, -2.61290323, -2.41935484, -2.22580645,
#        -2.03225806, -1.83870968, -1.64516129, -1.4516129 , -1.25806452,
#        -1.06451613, -0.87096774, -0.67741935, -0.48387097, -0.29032258,
#        -0.09677419,  0.09677419,  0.29032258,  0.48387097,  0.67741935,
#         0.87096774,  1.06451613,  1.25806452,  1.4516129 ,  1.64516129,
#         1.83870968,  2.03225806,  2.22580645,  2.41935484,  2.61290323,
#         2.80645161,  3.        ])
