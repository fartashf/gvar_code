# %%
import torch
from torch.autograd import Variable
import numpy as np
import pylab as plt
# %matplotlib inline
import torchvision.utils as vutils
import glob

# %%
import sys
sys.path.append('../')
import models
import models.mnist
from data import get_loaders
from utils import DictWrapper

# %%
# %load_ext autoreload
# %autoreload 1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %aimport log_plotter
from log_plotter import get_run_names, get_data, get_data_pth, plot_smooth, plot_tag, plot_runs_and_tags, get_legend, plot_smooth_o1, plot_smooth_o2, plot_clusters_online, plot_smooth_shade, plot_runs_and_tags_multi, plot_smooth_o5

# %%
save_single = True
no_title = True

# %% [markdown]
# ## linreg corrected noise model, snr=5, nonzero w_*, $\gamma=2$

# %%
get_data_f = get_data_pth
plot_f = plt.plot
plot_f = plot_smooth_shade
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_linreg_dim1000_niters1e5_bs10_lr5e-5_snr_10/']  # (?!.*scheduler)
tag_names = ['Tloss', 'est_var', 'gb_td']
fig_name = 'figs_neurips2020/linreg_dim1000_niters1e5_bs10_lr5e-5_snr_10.png'
lg_tags = ['estim_sgd', 'svrg', 'gluster', 'batch_size']  # g_estim
# ylim = [None]*20
ylim = [None, None, None, [0, 1e-1], None]
# ylim = [None, [0, 3e-6], None, None, [98, 100], [98, 100]]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 4
smooth_div_ns = [20, 20, 2]
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('batch_size_', 'B='), (',B=20', '2B'), (',B=10', '-B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, smooth_div_ns=smooth_div_ns)

# %% [markdown]
# ## duplicates

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_shade
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_linreg_dim1000_niters1e5_bs10_lr5e-5_snr_10_dup/']  # (?!.*scheduler)
tag_names = ['Tloss', 'est_var', 'gb_td']
fig_name = 'figs_neurips2020/linreg_dim1000_niters1e5_bs10_lr5e-5_snr_10_dup.png'
lg_tags = ['estim_sgd', 'svrg', 'gluster', 'batch_size']  # g_estim
# ylim = [None]*20
ylim = [None, None, None, [0, 1e-1], None]
# ylim = [None, [0, 3e-6], None, None, [98, 100], [98, 100]]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 4
smooth_div_ns = [20, 20, 2]
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('batch_size_', 'B='), (',B=20', '2B'), (',B=10', '-B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, smooth_div_ns=smooth_div_ns)

# %% [markdown]
# # MNIST

# %% [markdown]
# ## mlp

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_shade
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_gvar/.*mlp(?!.*g_nclusters_8)']  # (?!.*scheduler)
tag_names = ['grad_bias', 'est_var', 'est_nvar', 'gb_td']
fig_name = 'figs_neurips2020/mnist_mlp.png'
lg_tags = ['estim_sgd', 'svrg', 'gluster', 'g_batch_size']  # g_estim, , 'g_nclusters'
# ylim = [None]*20
ylim = [None, [0, 5e-8], None, None, None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 5
smooth_div_ns = [2, 2, 2, 2]
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('g_batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, smooth_div_ns=smooth_div_ns)

# %% [markdown]
# ## cnn

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_shade
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_gvar/.*cnn']  # (?!.*scheduler)
tag_names = ['grad_bias', 'est_var', 'est_nvar', 'gb_td']
fig_name = 'figs_neurips2020/mnist_cnn.png'
lg_tags = ['estim_sgd', 'svrg', 'gluster', 'g_batch_size']  # g_estim
# ylim = [None]*20
ylim = [None, [0, 5e-8], None, None, None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 5
smooth_div_ns = [2, 5, 2, 1.1]
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('g_batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, smooth_div_ns=smooth_div_ns)

# %% [markdown]
# # Cifar10

# %% [markdown]
# ## resnet8

# %% [markdown]
# ### example of difference

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_shade
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_resnet8_data/.*dup']  # (?!.*scheduler)
tag_names = ['est_var']
fig_name = 'figs_neurips2020/cifar10_resnet8_dup.png'
lg_tags = ['estim_sgd', 'svrg', 'gluster', 'batch_size', 'g_avg', 'msnap_iter']  # g_estim
# ylim = [None]*20
ylim = [[0, 1e-4]]
# ylim = [None, [0, 2e-5], None, None, None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 5
smooth_div_ns = [5, 2, 2, 2]
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, smooth_div_ns=smooth_div_ns)

# %% [markdown]
# ## Resnet8 product of data aug, label smooth, corrupt

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_shade
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_resnet8_data_prod/(?!.*smoothing)(?!.*data_aug)(?!.*corrupt)']  # (?!.*scheduler)
tag_names = ['est_var', 'est_nvar']
fig_name = 'figs_neurips2020/cifar10_resnet8_nodataprod.png'
lg_tags = ['estim_sgd', 'svrg', 'gluster', 'batch_size', 'g_avg', 'msnap_iter']  # g_estim
ylim = [None]*20
# ylim = [None, [0, 2e-5], None, None, None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 5
no_title = True
save_single = True
smooth_div_ns = [5, 2, 2, 2]
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, smooth_div_ns=smooth_div_ns)

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_shade
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_resnet8_data_prod/(?!.*smoothing)(?!.*data_aug).*corrupt']  # (?!.*scheduler)
tag_names = ['est_var']
fig_name = 'figs_neurips2020/cifar10_resnet8_corrupt.png'
lg_tags = ['estim_sgd', 'svrg', 'gluster', 'batch_size', 'g_avg', 'msnap_iter']  # g_estim
ylim = [None]*20
# ylim = [None, [0, 2e-5], None, None, None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 5
no_title = True
save_single = True
smooth_div_ns = [5, 2, 2, 2]
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, smooth_div_ns=smooth_div_ns)

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_shade
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_resnet8_data_prod/.*smoothing(?!.*data_aug)(?!.*corrupt)']  # (?!.*scheduler)
tag_names = ['est_var']
fig_name = 'figs_neurips2020/cifar10_resnet8_smoothing.png'
lg_tags = ['estim_sgd', 'svrg', 'gluster', 'batch_size', 'g_avg', 'msnap_iter']  # g_estim
ylim = [None]*20
# ylim = [None, [0, 2e-5], None, None, None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 5
no_title = True
save_single = True
smooth_div_ns = [5, 2, 2, 2]
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, smooth_div_ns=smooth_div_ns)

# %% [markdown]
# # Cifar100, Resnet32, label smooth, corrupt

# %% [markdown]
# ## cifar100, corrupt + dup

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_shade
logdir = '/u/faghri/dmom/code/runs/'
# patterns = ['.*runs_cifar100_gvar_resnet32_corrupt_dup/.*corrupt']  # (?!.*scheduler)
patterns = ['.*runs_cifar100_gvar_resnet32_corrupt_dup/(?!.*corrupt)']  # (?!.*scheduler)
# patterns = ['.*runs_cifar100_gvar_resnet32_corrupt_dup/.*']  # (?!.*scheduler)
tag_names = ['grad_bias', 'est_var', 'est_nvar', 'gb_td']
fig_name = 'figs_neurips2020/cifar100_resnet32_dup.png'
lg_tags = ['estim_sgd', 'svrg', 'gluster', 'batch_size', 'g_avg', 'msnap_iter', 'perc_']  # g_estim
# ylim = [None]*20
ylim = [[1e-4, 6e-4], [0, 2e-5], None, None, None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 4
smooth_div_ns = [2, 2, 2, 1]
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, smooth_div_ns=smooth_div_ns)

# %% [markdown]
# # Imagenet

# %% [markdown]
# ## kahan sum

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_shade
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_imagenet_gvar_kahan/']  # (?!.*scheduler)
tag_names = ['grad_bias', 'est_var', 'est_nvar', 'gb_td']
fig_name = 'figs_neurips2020/imagenet_kahan.png'
lg_tags = ['estim_sgd', 'svrg', 'gluster', 'batch_size']  # g_estim, 'g_nclusters', 
ylim = [None]*20
# ylim = [[1e-4, 6e-4], [0, 2e-5], None, None, None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = [0, 1, 3, 2]
smooth_div_ns = [2, 5, 5, 2]
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, smooth_div_ns=smooth_div_ns)

# %% [markdown]
# # Random Features

# %% [markdown]
# ## momentum=0, hs/N

# %%
plot_f = plt.scatter
# plot_f = plot_smooth_o1  # plot_smooth_o5
logdir = '/u/faghri/dmom/code/runs/runs_rf/'
patterns = ['.*runs_rf_gvar_hs1000_hsN/.*lr_0.001,']  # (?!.*scheduler) (.*estim_gluster|.*estim_sgd) .*num_train_data_100, (?!.*teacher_hidden_500,)
plot_tags = ['est_var', 'est_var']  # , 'est_nvar'
x_tags = ['student_hidden/num_train_data', 'student_hidden/num_train_data']  # 'student_hidden/teacher_hidden' 'teacher_hidden/num_train_data', 
y_tags = [None, None]
lg_tags = [['estim_', 'g_batch_size'], ['estim_', 'g_batch_size']]
fig_name = 'figs_rf/rf_agg_lr0.001.png'
# ylim = [[0, 1e-2], [0, 1e-2]]
ylim = [[1e-7, 1e-1], [1e-7, 1e-1]]
# ylim = [None]*20
ncolor = 4
agg_types = ['mean_70', 'max_70']
lg_replace = [('estim_', ''), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('g_batch_size_', 'B='), (',B=10', '-B'), (',B=20', '-2B'), ('nclusters_', 'C=')]
data, run_names = plot_runs_and_tags_multi(plot_f, logdir, patterns, plot_tags, x_tags, y_tags, lg_tags, fig_name, ylim, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, agg_types=agg_types)

# %%
plot_f = plt.scatter
# plot_f = plot_smooth_o1  # plot_smooth_o5
logdir = '/u/faghri/dmom/code/runs/runs_rf/'
patterns = ['.*runs_rf_gvar_hs1000_hsN/.*lr_0.01,']  # (?!.*scheduler) (.*estim_gluster|.*estim_sgd) .*num_train_data_100, (?!.*teacher_hidden_500,)
plot_tags = ['est_var', 'est_var']
x_tags = ['student_hidden/num_train_data', 'student_hidden/num_train_data']  # 'student_hidden/teacher_hidden' 'teacher_hidden/num_train_data', 
y_tags = [None, None]
lg_tags = [['estim_', 'g_batch_size'], ['estim_', 'g_batch_size']]
fig_name = 'figs_rf/rf_agg_lr0.01.png'
# ylim = [[0, 1e-2], [0, 1e-2]]
ylim = [[1e-7, 1e-1], [1e-7, 1e-1]]
# ylim = [None]*20
ncolor = 4
agg_types = ['mean_70', 'max_70']
lg_replace = [('estim_', ''), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('g_batch_size_', 'B='), (',B=10', '-B'), (',B=20', '-2B'), ('nclusters_', 'C=')]
data, run_names = plot_runs_and_tags_multi(plot_f, logdir, patterns, plot_tags, x_tags, y_tags, lg_tags, fig_name, ylim, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, agg_types=agg_types)

# %%
plot_f = plt.scatter
# plot_f = plot_smooth_o1  # plot_smooth_o5
logdir = '/u/faghri/dmom/code/runs/runs_rf/'
patterns = ['.*runs_rf_gvar_hs1000_hsN/.*lr_0.1,']  # (?!.*scheduler) (.*estim_gluster|.*estim_sgd) .*num_train_data_100, (?!.*teacher_hidden_500,)
plot_tags = ['est_var', 'est_var']
x_tags = ['student_hidden/num_train_data', 'student_hidden/num_train_data']  # 'student_hidden/teacher_hidden' 'teacher_hidden/num_train_data', 
y_tags = [None, None]
lg_tags = [['estim_', 'g_batch_size'], ['estim_', 'g_batch_size']]
fig_name = 'figs_rf/rf_agg_lr0.1.png'
# ylim = [[0, 1e-2], [0, 1e-2]]
ylim = [[1e-9, 1e-1], [1e-9, 1e-1]]
# ylim = [None]*20
ncolor = 4
agg_types = ['mean_70', 'max_70']
lg_replace = [('estim_', ''), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('g_batch_size_', 'B='), (',B=10', '-B'), (',B=20', '-2B'), ('nclusters_', 'C=')]
data, run_names = plot_runs_and_tags_multi(plot_f, logdir, patterns, plot_tags, x_tags, y_tags, lg_tags, fig_name, ylim, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, agg_types=agg_types)

# %%
plot_f = plt.scatter
# plot_f = plot_smooth_o1  # plot_smooth_o5
logdir = '/u/faghri/dmom/code/runs/runs_rf/'
patterns = ['.*runs_rf_gvar_hs1000_hsN/.*estim_sgd.*g_batch_size_10']  # (?!.*scheduler) (.*estim_gluster|.*estim_sgd) .*num_train_data_100, (?!.*teacher_hidden_500,)
plot_tags = ['est_var', 'est_var']
x_tags = ['student_hidden/num_train_data', 'student_hidden/num_train_data']  # 'student_hidden/teacher_hidden' 'teacher_hidden/num_train_data', 
y_tags = [None, None]
lg_tags = [['estim_', 'lr'], ['estim_', 'lr']]
fig_name = 'figs_rf/rf_agg_sgd.png'
# ylim = [[0, 1e-2], [0, 1e-2]]
ylim = [[1e-9, 1e-1], [1e-9, 1e-1]]
# ylim = [None]*20
ncolor = 4
agg_types = ['mean_70', 'max_70']
lg_replace = [('lr_', 'LR='), ('estim_', ''), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('g_batch_size_', 'B='), (',B=10', '-B'), (',B=20', '-2B'), ('nclusters_', 'C=')]
data, run_names = plot_runs_and_tags_multi(plot_f, logdir, patterns, plot_tags, x_tags, y_tags, lg_tags, fig_name, ylim, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, agg_types=agg_types)

# %% [markdown]
# ## duplicates

# %%
plot_f = plt.scatter
# plot_f = plot_smooth_o1  # plot_smooth_o5
logdir = '/u/faghri/dmom/code/runs/runs_rf/'
patterns = ['.*runs_rf_gvar_hs1000_hsN_dup5,0.1/.*lr_0.01,']  # (?!.*scheduler) (.*estim_gluster|.*estim_sgd) .*num_train_data_100, (?!.*teacher_hidden_500,)
plot_tags = ['est_var', 'est_var']
x_tags = ['student_hidden/num_train_data', 'student_hidden/num_train_data']  # 'student_hidden/teacher_hidden' 'teacher_hidden/num_train_data', 
y_tags = [None, None]
lg_tags = [['estim_', 'g_batch_size'], ['estim_', 'g_batch_size']]
fig_name = 'figs_rf/rf_agg_dup_5,0.1_lr0.01.png'
# ylim = [[0, 1e-2], [0, 1e-2]]
ylim = [[1e-7, 1e-2], [1e-7, 1e-2]]
# ylim = [None]*20
ncolor = 4
agg_types = ['mean_70', 'max_70']
lg_replace = [('estim_', ''), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('g_batch_size_', 'B='), (',B=10', '-B'), (',B=20', '-2B'), ('nclusters_', 'C=')]
data, run_names = plot_runs_and_tags_multi(plot_f, logdir, patterns, plot_tags, x_tags, y_tags, lg_tags, fig_name, ylim, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, agg_types=agg_types)

# %%
plot_f = plt.scatter
# plot_f = plot_smooth_o1  # plot_smooth_o5
logdir = '/u/faghri/dmom/code/runs/runs_rf/'
patterns = ['.*runs_rf_gvar_hs1000_hsN_dup5,0.5/.*lr_0.01,']  # (?!.*scheduler) (.*estim_gluster|.*estim_sgd) .*num_train_data_100, (?!.*teacher_hidden_500,)
plot_tags = ['est_var', 'est_var']
x_tags = ['student_hidden/num_train_data', 'student_hidden/num_train_data']  # 'student_hidden/teacher_hidden' 'teacher_hidden/num_train_data', 
y_tags = [None, None]
lg_tags = [['estim_', 'g_batch_size'], ['estim_', 'g_batch_size']]
fig_name = 'figs_rf/rf_agg_dup_5,0.5_lr0.01.png'
# ylim = [[0, 1e-2], [0, 1e-2]]
ylim = [[1e-7, 1e-2], [1e-7, 1e-2]]
# ylim = [None]*20
ncolor = 4
agg_types = ['mean_70', 'max_70']
lg_replace = [('estim_', ''), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('g_batch_size_', 'B='), (',B=10', '-B'), (',B=20', '-2B'), ('nclusters_', 'C=')]
data, run_names = plot_runs_and_tags_multi(plot_f, logdir, patterns, plot_tags, x_tags, y_tags, lg_tags, fig_name, ylim, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, agg_types=agg_types)

# %%
plot_f = plt.scatter
# plot_f = plot_smooth_o1  # plot_smooth_o5
logdir = '/u/faghri/dmom/code/runs/runs_rf/'
patterns = ['.*runs_rf_gvar_hs1000_hsN_dup5,0.9/.*lr_0.01,']  # (?!.*scheduler) (.*estim_gluster|.*estim_sgd) .*num_train_data_100, (?!.*teacher_hidden_500,)
plot_tags = ['est_var', 'est_var']
x_tags = ['student_hidden/num_train_data', 'student_hidden/num_train_data']  # 'student_hidden/teacher_hidden' 'teacher_hidden/num_train_data', 
y_tags = [None, None]
lg_tags = [['estim_', 'g_batch_size'], ['estim_', 'g_batch_size']]
fig_name = 'figs_rf/rf_agg_dup_5,0.9_lr0.01.png'
# ylim = [[0, 1e-2], [0, 1e-2]]
ylim = [[1e-7, 1e-2], [1e-7, 1e-2]]
# ylim = [None]*20
ncolor = 4
agg_types = ['mean_70', 'max_70']
lg_replace = [('estim_', ''), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('g_batch_size_', 'B='), (',B=10', '-B'), (',B=20', '-2B'), ('nclusters_', 'C=')]
data, run_names = plot_runs_and_tags_multi(plot_f, logdir, patterns, plot_tags, x_tags, y_tags, lg_tags, fig_name, ylim, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, agg_types=agg_types)

# %% [markdown]
# ## normalized variance

# %%
plot_f = plt.scatter
# plot_f = plot_smooth_o1  # plot_smooth_o5
logdir = '/u/faghri/dmom/code/runs/runs_rf/'
patterns = ['.*runs_rf_gvar_hs1000_hsN/.*estim_sgd.*g_batch_size_10']  # (?!.*scheduler) (.*estim_gluster|.*estim_sgd) .*num_train_data_100, (?!.*teacher_hidden_500,)
plot_tags = ['est_nvar', 'est_nvar']
x_tags = ['student_hidden/num_train_data', 'student_hidden/num_train_data']  # 'student_hidden/teacher_hidden' 'teacher_hidden/num_train_data', 
y_tags = [None, None]
lg_tags = [['estim_', 'g_batch_size', 'lr'], ['estim_', 'g_batch_size', 'lr']]
fig_name = 'figs_rf/rf_agg_sgd.png'
# ylim = [[0, 1e-2], [0, 1e-2]]
# ylim = [[1e-9, 1e-1], [1e-9, 1e-1]]
# ylim = [None]*20
ylim= [[0.2, 2], [0.2, 2]]
ncolor = 4
agg_types = ['mean_70', 'max_70']
lg_replace = [('lr_', 'LR='), ('estim_', ''), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('g_batch_size_', 'B='), (',B=10', '-B'), (',B=20', '-2B'), ('nclusters_', 'C=')]
data, run_names = plot_runs_and_tags_multi(plot_f, logdir, patterns, plot_tags, x_tags, y_tags, lg_tags, fig_name, ylim, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, agg_types=agg_types)

# %%
plot_f = plt.scatter
# plot_f = plot_smooth_o1  # plot_smooth_o5
logdir = '/u/faghri/dmom/code/runs/runs_rf/'
patterns = ['.*runs_rf_gvar_hs1000_hsN/.*lr_0.1,']  # (?!.*scheduler) (.*estim_gluster|.*estim_sgd) .*num_train_data_100, (?!.*teacher_hidden_500,)
plot_tags = ['est_nvar', 'est_nvar']
x_tags = ['student_hidden/num_train_data', 'student_hidden/num_train_data']  # 'student_hidden/teacher_hidden' 'teacher_hidden/num_train_data', 
y_tags = [None, None]
lg_tags = [['estim_', 'g_batch_size'], ['estim_', 'g_batch_size']]
fig_name = 'figs_rf/rf_agg_lr0.1.png'
# ylim = [[0, 1e-2], [0, 1e-2]]
# ylim = [[1e-9, 1e-1], [1e-9, 1e-1]]
# ylim = [None]*20
ylim= [[0.2, 2], [0.2, 2]]
ncolor = 4
agg_types = ['mean_70', 'max_70']
lg_replace = [('estim_', ''), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('g_batch_size_', 'B='), (',B=10', '-B'), (',B=20', '-2B'), ('nclusters_', 'C=')]
data, run_names = plot_runs_and_tags_multi(plot_f, logdir, patterns, plot_tags, x_tags, y_tags, lg_tags, fig_name, ylim, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, agg_types=agg_types)

# %%
plot_f = plt.scatter
# plot_f = plot_smooth_o1  # plot_smooth_o5
logdir = '/u/faghri/dmom/code/runs/runs_rf/'
patterns = ['.*runs_rf_gvar_hs1000_hsN/.*lr_0.01,']  # (?!.*scheduler) (.*estim_gluster|.*estim_sgd) .*num_train_data_100, (?!.*teacher_hidden_500,)
plot_tags = ['est_nvar', 'est_nvar']
x_tags = ['student_hidden/num_train_data', 'student_hidden/num_train_data']  # 'student_hidden/teacher_hidden' 'teacher_hidden/num_train_data', 
y_tags = [None, None]
lg_tags = [['estim_', 'g_batch_size'], ['estim_', 'g_batch_size']]
fig_name = 'figs_rf/rf_agg_lr0.01.png'
# ylim = [[0, 1e-2], [0, 1e-2]]
# ylim = [[1e-9, 1e-1], [1e-9, 1e-1]]
# ylim = [None]*20
ylim= [[0.2, 2], [0.2, 2]]
ncolor = 4
agg_types = ['mean_70', 'max_70']
lg_replace = [('estim_', ''), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('g_batch_size_', 'B='), (',B=10', '-B'), (',B=20', '-2B'), ('nclusters_', 'C=')]
data, run_names = plot_runs_and_tags_multi(plot_f, logdir, patterns, plot_tags, x_tags, y_tags, lg_tags, fig_name, ylim, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, agg_types=agg_types)

# %%
plot_f = plt.scatter
# plot_f = plot_smooth_o1  # plot_smooth_o5
logdir = '/u/faghri/dmom/code/runs/runs_rf/'
patterns = ['.*runs_rf_gvar_hs1000_hsN/.*lr_0.001,']  # (?!.*scheduler) (.*estim_gluster|.*estim_sgd) .*num_train_data_100, (?!.*teacher_hidden_500,)
plot_tags = ['est_nvar', 'est_nvar']
x_tags = ['student_hidden/num_train_data', 'student_hidden/num_train_data']  # 'student_hidden/teacher_hidden' 'teacher_hidden/num_train_data', 
y_tags = [None, None]
lg_tags = [['estim_', 'g_batch_size'], ['estim_', 'g_batch_size']]
fig_name = 'figs_rf/rf_agg_lr0.001.png'
# ylim = [[0, 1e-2], [0, 1e-2]]
# ylim = [[1e-9, 1e-1], [1e-9, 1e-1]]
# ylim = [None]*20
ylim= [[0.2, 2], [0.2, 2]]
ncolor = 4
agg_types = ['mean_70', 'max_70']
lg_replace = [('estim_', ''), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('g_batch_size_', 'B='), (',B=10', '-B'), (',B=20', '-2B'), ('nclusters_', 'C=')]
data, run_names = plot_runs_and_tags_multi(plot_f, logdir, patterns, plot_tags, x_tags, y_tags, lg_tags, fig_name, ylim, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, agg_types=agg_types)

# %% [markdown]
# # Normalized variance

# %% [markdown]
# ## mlp

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_shade
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_gvar/.*mlp(.*estim_sgd.*g_batch_size_128)']  # (?!.*scheduler)
tag_names = ['grad_bias', 'est_var', 'est_nvar', 'gb_td']
fig_name = 'figs_neurips2020/mnist_mlp_nvar.png'
lg_tags = ['estim_sgd', 'svrg', 'gluster', 'g_batch_size']  # g_estim, , 'g_nclusters'
# ylim = [None]*20
ylim = [None, [0, 5e-8], None, None, None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 5
smooth_div_ns = [2, 2, 2, 2]
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('g_batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, smooth_div_ns=smooth_div_ns)

# %% [markdown]
# ## cnn

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_shade
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_gvar/.*cnn(.*estim_sgd.*g_batch_size_128)']  # (?!.*scheduler)
tag_names = ['grad_bias', 'est_var', 'est_nvar', 'gb_td']
fig_name = 'figs_neurips2020/mnist_cnn_nvar.png'
lg_tags = ['estim_sgd', 'svrg', 'gluster', 'g_batch_size']  # g_estim
# ylim = [None]*20
ylim = [None, [0, 5e-8], None, None, None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 5
smooth_div_ns = [2, 5, 2, 1.1]
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('g_batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, smooth_div_ns=smooth_div_ns)

# %% [markdown]
# ## cifar10

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_shade
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_resnet8_data_prod/(?!.*smoothing)(?!.*data_aug)(?!.*corrupt)(.*estim_sgd.*g_batch_size_128)']  # (?!.*scheduler)
tag_names = ['est_var', 'est_nvar']
fig_name = 'figs_neurips2020/cifar10_resnet8_nodataprod_nvar.png'
lg_tags = ['estim_sgd', 'svrg', 'gluster', 'batch_size', 'g_avg', 'msnap_iter']  # g_estim
ylim = [None]*20
# ylim = [None, [0, 2e-5], None, None, None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 5
no_title = True
save_single = True
smooth_div_ns = [5, 2, 2, 2]
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, smooth_div_ns=smooth_div_ns)

# %% [markdown]
# ## imagenet

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_shade
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_imagenet_gvar_kahan/(.*estim_sgd.*g_batch_size_128)']  # (?!.*scheduler)
tag_names = ['grad_bias', 'est_var', 'est_nvar', 'gb_td']
fig_name = 'figs_neurips2020/imagenet_kahan_nvar.png'
lg_tags = ['estim_sgd', 'svrg', 'gluster', 'batch_size']  # g_estim, 'g_nclusters', 
ylim = [None]*20
# ylim = [[1e-4, 6e-4], [0, 2e-5], None, None, None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = [0, 1, 3, 2]
smooth_div_ns = [2, 5, 5, 2]
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, smooth_div_ns=smooth_div_ns)

# %% [markdown]
# # Plot vs C

# %% [markdown]
# ## mnist

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_nclusters/.*mnist']  # (?!.*scheduler)
tag_names = ['gb_td']
fig_name = 'figs_neurips2020/mnist_nclusters.png'
lg_tags = ['g_nclusters', 'duplicate']  # g_estim
ylim = [None]*20
sep_h = True
ncolor = 4
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title)
td = [data[i]['gb_td'][1] for i in range(len(data))]
plt.clf()

patterns = ['.*runs_nclusters_randi/']  # (?!.*scheduler)
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title)
td_rand = [data[i]['gb_td'][1] for i in range(len(data))]




plt.clf()
nclusters = np.power(2, np.arange(len(data)))
plt.plot(nclusters, td[0]/nclusters, label='$D_0/C$', c='b')
plt.plot(nclusters, td_rand, label='Rand', c='b', ls='--')
plt.plot(nclusters, td, label='GC', c='r')
plt.plot(nclusters, td[0]/(2*nclusters), label=r'$D_0/2C$', c='b', ls='-.')
plt.plot(nclusters, td[0]/(nclusters**2), label=r'$D_0/C^2$', c='b', ls=':')
plt.xlabel('Total distortion')
plt.ylabel('Number of Clusters')
ax = plt.gca()
ax.set_yscale('log')
plt.savefig('figs_plotc/mnist_nolegend.pdf', dpi=100, bbox_inches='tight')
plt.legend()
plt.savefig('figs_plotc/mnist.pdf', dpi=100, bbox_inches='tight')

# %% [markdown]
# ## cifar10

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_nclusters/.*cifar10(?!.*duplicate)']  # (?!.*scheduler)
tag_names = ['gb_td']
fig_name = 'figs_neurips2020/cifar10_nclusters.png'
lg_tags = ['g_nclusters', 'duplicate']  # g_estim
ylim = [None]*20
sep_h = True
ncolor = 4
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title)
td = [data[i]['gb_td'][1] for i in range(len(data))]



plt.clf()
nclusters = np.power(2, np.arange(len(data)))
plt.plot(nclusters, td[0]/nclusters, label='$D_0/C$', c='b')
plt.plot(nclusters, td, label='GC', c='r')
plt.plot(nclusters, td[0]/(2*nclusters), label=r'$D_0/2C$', c='b', ls='-.')
plt.plot(nclusters, td[0]/(nclusters**2), label=r'$D_0/C^2$', c='b', ls=':')
plt.xlabel('Total distortion')
plt.ylabel('Number of Clusters')
ax = plt.gca()
ax.set_yscale('log')
plt.savefig('figs_plotc/cifar10_nolegend.pdf', dpi=100, bbox_inches='tight')
plt.legend()
plt.savefig('figs_plotc/cifar10.pdf', dpi=100, bbox_inches='tight')

# %% [markdown]
# ## imagenet

# %%
get_data_f = get_data_pth
plot_f = plt.plot
# plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_nclusters/.*imagenet(.*kahan)']  # (?!.*scheduler)
tag_names = ['gb_td']
fig_name = 'figs_neurips2020/imagenet_nclusters.png'
lg_tags = ['g_nclusters', 'duplicate']  # g_estim
ylim = [None]*20
sep_h = True
ncolor = 4
lg_replace = [('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title)
td = [data[i]['gb_td'][1] for i in range(len(data))]



plt.clf()
nclusters = np.power(2, np.arange(len(data)))
plt.plot(nclusters, td[0]/nclusters, label='$D_0/C$', c='b')
plt.plot(nclusters, td, label='GC', c='r')
plt.plot(nclusters, td[0]/(2*nclusters), label=r'$D_0/2C$', c='b', ls='-.')
plt.plot(nclusters, td[0]/(nclusters**2), label=r'$D_0/C^2$', c='b', ls=':')
plt.xlabel('Total distortion')
plt.ylabel('Number of Clusters')
ax = plt.gca()
ax.set_yscale('log')
plt.savefig('figs_plotc/imagenet_nolegend.pdf', dpi=100, bbox_inches='tight')
plt.legend()
plt.savefig('figs_plotc/imagenet.pdf', dpi=100, bbox_inches='tight')
