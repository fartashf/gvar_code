# %%
import torch
from torch.autograd import Variable
import numpy as np
import pylab as plt
# %matplotlib inline
import torchvision.utils as vutils
import glob

# %%
import sys
sys.path.append('../')
import models
import models.mnist
from data import get_loaders
from utils import DictWrapper

# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport log_plotter
from log_plotter import get_run_names, get_data, get_data_pth, plot_smooth, plot_tag, plot_runs_and_tags, get_legend, plot_smooth_o1, plot_smooth_o2, plot_clusters_online, plot_smooth_shade, plot_runs_and_tags_multi, plot_smooth_o5

# %%
save_single = False
no_title = False

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_shade
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_gnorm/.*g_batch_size_128']  # (?!.*scheduler)
tag_names = ['est_gnorm', 'est_var', 'est_nvar']
fig_name = 'figs_gnorm/mnist_cifar10_cifar100_imagenet.png'
lg_tags = ['dataset']  # g_estim, 'g_nclusters', 
ylim = [None]*20
sep_h = True
ncolor = 4
smooth_div_ns = [2, 5, 5, 2]
lg_replace = [('dataset_', ''), ('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, smooth_div_ns=smooth_div_ns)

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_shade
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_gnorm/.*(mnist|imagenet).*g_batch_size_128']  # (?!.*scheduler)
tag_names = ['est_gnorm', 'est_var', 'est_nvar']
fig_name = 'figs_gnorm/mnist_imagenet.png'
lg_tags = ['dataset']  # g_estim, 'g_nclusters', 
ylim = [None]*20
sep_h = True
ncolor = 4
smooth_div_ns = [2, 5, 5, 2]
lg_replace = [('dataset_', ''), ('estim_sgd', 'sgd'), (' ', ','), ('g_nclusters_', 'C='), ('sgd', 'SG'), ('svrg', 'SVRG'), ('gluster', 'GC'), ('g_osnap_iter_', 'Oi='), ('g_beta_', 'beta='), ('g_min_size_', 'sz='), ('duplicate_10', 'Dup'), ('batch_size_', 'B='), (',B=128', '-B'), (',B=256', '-2B')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, no_title=no_title, smooth_div_ns=smooth_div_ns)
