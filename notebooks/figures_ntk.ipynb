# %%
import torch
from torch.autograd import Variable
import numpy as np
import pylab as plt
# %matplotlib inline
import torchvision.utils as vutils
import glob

# %%
import sys
sys.path.append('../')
import models
import models.mnist
from data import get_loaders
from utils import DictWrapper

# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport log_plotter
from log_plotter import get_run_names, get_data, get_data_pth, plot_smooth, plot_tag, plot_runs_and_tags, get_legend, plot_smooth_o1

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_ntk/(00_.*|.*weight_decay_0,(?!.*estim_sgd))']  # (?!.*scheduler)
tag_names = ['grad_bias', 'est_var', 'Tacc', 'Vacc', 'Tloss', 'Vloss']  # 'lr', 'gb_td', 
fig_name = 'figs_ntk/cifar10.png'
lg_tags = ['estim_sgd', 'estim_ntk', 'lr_', 'damping_']
ylim = [None]*20
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 4
lg_replace = [('estim_sgd', 'SGD,'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_ntk/(00_.*|.*weight_decay_0.0001,.*estim_ntk)']  # (?!.*scheduler)
tag_names = ['grad_bias', 'est_var', 'Tacc', 'Vacc', 'Tloss', 'Vloss']  # 'lr', 'gb_td', 
fig_name = 'figs_ntk/cifar10_wd.png'
lg_tags = ['estim_sgd', 'estim_ntk', 'lr_', 'damping_']
ylim = [None]*20
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 4
lg_replace = [('estim_sgd', 'SGD,'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_ntk/(00_.*|.*weight_decay_0,.*estim_ntk)']  # (?!.*scheduler)
tag_names = ['grad_bias', 'est_var', 'Tacc', 'Vacc', 'Tloss', 'Vloss']  # 'lr', 'gb_td', 
fig_name = 'figs_ntk/cifar10_wd.png'
lg_tags = ['estim_sgd', 'estim_ntk', 'lr_', 'damping_']
ylim = [None]*20
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 4
lg_replace = [('estim_sgd', 'SGD,'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)
