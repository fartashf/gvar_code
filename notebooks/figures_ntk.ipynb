# %%
import torch
from torch.autograd import Variable
import numpy as np
import pylab as plt
# %matplotlib inline
import torchvision.utils as vutils
import glob

# %%
import sys
sys.path.append('../')
import models
import models.mnist
from data import get_loaders
from utils import DictWrapper

# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport log_plotter
from log_plotter import get_run_names, get_data, get_data_pth, plot_smooth, plot_tag, plot_runs_and_tags, get_legend, plot_smooth_o1

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_ntk/(00_.*|.*weight_decay_0,(?!.*estim_sgd).*lr_0.005)']  # (?!.*scheduler)
tag_names = ['grad_bias', 'est_var', 'Tacc', 'Vacc', 'Tloss', 'Vloss']  # 'lr', 'gb_td', 
fig_name = 'figs_ntk/cifar10.png'
lg_tags = ['estim_sgd', 'estim_ntk', 'lr_', 'damping_']
ylim = [None]*20
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 4
lg_replace = [('estim_sgd', 'SGD,'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_ntk/(00_.*|.*weight_decay_0,(?!.*estim_sgd).*lr_0.002)']  # (?!.*scheduler)
tag_names = ['grad_bias', 'est_var', 'Tacc', 'Vacc', 'Tloss', 'Vloss']  # 'lr', 'gb_td', 
fig_name = 'figs_ntk/cifar10.png'
lg_tags = ['estim_sgd', 'estim_ntk', 'lr_', 'damping_']
ylim = [None]*20
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 4
lg_replace = [('estim_sgd', 'SGD,'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_ntk/(00_.*|.*weight_decay_0,(?!.*estim_sgd).*lr_0.001)']  # (?!.*scheduler)
tag_names = ['grad_bias', 'est_var', 'Tacc', 'Vacc', 'Tloss', 'Vloss']  # 'lr', 'gb_td', 
fig_name = 'figs_ntk/cifar10.png'
lg_tags = ['estim_sgd', 'estim_ntk', 'lr_', 'damping_']
ylim = [None]*20
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 4
lg_replace = [('estim_sgd', 'SGD,'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_ntk/(00_.*|.*weight_decay_0,(?!.*estim_sgd).*lr_0.0005)']  # (?!.*scheduler)
tag_names = ['grad_bias', 'est_var', 'Tacc', 'Vacc', 'Tloss', 'Vloss']  # 'lr', 'gb_td', 
fig_name = 'figs_ntk/cifar10.png'
lg_tags = ['estim_sgd', 'estim_ntk', 'lr_', 'damping_']
ylim = [None]*20
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 4
lg_replace = [('estim_sgd', 'SGD,'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)

# %% [markdown]
# # Optimal damping for each LR

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_ntk/(00_|20_|.*weight_decay_0,(?!.*estim_sgd)((?!.*lr_0.005).*damping_0.001|.*lr_0.005.*damping_0.1))']  # (?!.*scheduler)
tag_names = ['est_var', 'est_nvar', 'Tacc', 'Vacc', 'Tloss', 'Vloss']  # 'lr', 'gb_td', 'grad_bias',
fig_name = 'figs_ntk/cifar10.png'
lg_tags = ['estim_sgd', 'kfac', 'estim_ntk', 'lr_', 'damping_']
ylim = [None]*20
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 4
lg_replace = [('estim_sgd', 'SGD'), ('kfac', 'K-FAC'), ('SGD,K-FAC', 'K-FAC'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)

# %% [markdown]
# # VAE

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_ntk_vae/.*optim_sgd']  # (?!.*scheduler)
tag_names = ['est_var', 'est_nvar', 'loss']  # 'lr', 'gb_td', 'grad_bias',
fig_name = 'figs_ntk/mnist_vae.png'
lg_tags = ['estim_sgd', 'kfac', 'estim_ntk', 'lr_', 'damping_']
ylim = [None]*20
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 4
lg_replace = [('estim_sgd', 'SGD'), ('kfac', 'K-FAC'), ('SGD,K-FAC', 'K-FAC'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_ntk_vae/.*optim_adam']  # (?!.*scheduler)
tag_names = ['est_var', 'est_nvar', 'loss']  # 'lr', 'gb_td', 'grad_bias',
fig_name = 'figs_ntk/mnist_vae.png'
lg_tags = ['optim_adam', 'kfac', 'estim_ntk', 'lr_', 'damping_']
ylim = [None]*20
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 4
lg_replace = [('estim_sgd', 'SGD'), ('kfac', 'K-FAC'), ('SGD,K-FAC', 'K-FAC'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_mnist_ntk_vae/(.*estim_sgd.*optim_sgd.*lr_0.005|.*optim_adam.*lr_0.01|.*estim_ntk.*lr_0.01)']  # (?!.*scheduler)
tag_names = ['est_var', 'est_nvar', 'loss']  # 'lr', 'gb_td', 'grad_bias',
fig_name = 'figs_ntk/mnist_vae.png'
lg_tags = ['optim_sgd', 'adam', 'kfac', 'estim_ntk', 'lr_', 'damping_']
# ylim = [None]*20
ylim = [None, None, [0, 200]]
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 4
lg_replace = [('optim_sgd', 'SGD'), ('kfac', 'K-FAC'), ('SGD,K-FAC', 'K-FAC'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)

# %% [markdown]
# # fine hparam search

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_ntk/(00|08|.*ntk.*lr_0.005)']  # (?!.*scheduler)
tag_names = ['est_var', 'est_nvar', 'Tacc', 'Vacc', 'Tloss', 'Vloss']  # 'lr', 'gb_td', 'grad_bias',
fig_name = 'figs_ntk/cifar10.png'
lg_tags = ['optim_sgd', 'adam', 'kfac', 'estim_ntk', 'lr_', 'damping_']
ylim = [None]*20
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 4
lg_replace = [('optim_sgd', 'SGD'), ('kfac', 'K-FAC'), ('SGD,K-FAC', 'K-FAC'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)

# %%
# |.*lr_0.001.*damping_0.001|.*lr_0.002.*damping_0.005|.*lr_0.005.*damping_0.01

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_ntk/(00|08|.*lr_0.005.*damping_0.01)|.*runs_cifar10_gvar_ntk_bs128/(00|01|.*lr_0.005.*damping_0.01)']  # (?!.*scheduler)
tag_names = ['est_var', 'est_nvar', 'Tacc', 'Vacc', 'Tloss', 'Vloss']  # 'lr', 'gb_td', 'grad_bias',
fig_name = 'figs_ntk/cifar10.png'
lg_tags = ['estim_sgd', 'optim_sgd', 'adam', 'kfac', 'estim_ntk', 'batch_size_', 'lr_', 'damping_']
ylim = [None]*20
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 3
lg_replace = [('optim_sgd', 'SGD'), ('estim_sgd', 'SGD'), ('kfac', 'K-FAC'), ('SGD,K-FAC', 'K-FAC'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_ntk_bs128/(.*kfac.*lr_0.1.*damping_0.03|.*kfac.*lr_0.05.*damping_0.03|.*kfac.*lr_0.02.*damping_0.03)']  # (?!.*scheduler)
tag_names = ['est_var', 'est_nvar', 'Tacc', 'Vacc', 'Tloss', 'Vloss']  # 'lr', 'gb_td', 'grad_bias',
fig_name = 'figs_ntk/cifar10.png'
lg_tags = ['estim_sgd', 'optim_sgd', 'adam', 'kfac', 'estim_ntk', 'batch_size_', 'lr_', 'damping_']
ylim = [None]*20
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 3
lg_replace = [('optim_sgd', 'SGD'), ('estim_sgd', 'SGD'), ('kfac', 'K-FAC'), ('SGD,K-FAC', 'K-FAC'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)

# %% [markdown]
# # Large batch (1024), large model (resnet32)

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_ntk_bs1024/(00|01|.*lr_0.005.*damping_0.01|.*lr_0.01.*damping_0.03|.*lr_0.02.*damping_0.03)']  # (?!.*scheduler)
tag_names = ['est_var', 'est_nvar', 'Tacc', 'Vacc', 'Tloss', 'Vloss']  # 'lr', 'gb_td', 'grad_bias',
fig_name = 'figs_ntk/cifar10.png'
lg_tags = ['estim_sgd', 'optim_sgd', 'adam', 'kfac', 'estim_ntk', 'batch_size_', 'lr_', 'damping_']
ylim = [None]*20
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 5
lg_replace = [('optim_sgd', 'SGD'), ('estim_sgd', 'SGD'), ('kfac', 'K-FAC'), ('SGD,K-FAC', 'K-FAC'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)

# %%
Si=torch.load('../Si.pth.tar')

# %%
plt.plot(Si['Si'])

# %% [markdown]
# # SGD bs 1024

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_ntk_bs1024_sgd/(?!.*kfac)']  # (?!.*scheduler)
tag_names = ['est_var', 'est_nvar', 'Tacc', 'Vacc', 'Tloss', 'Vloss']  # 'lr', 'gb_td', 'grad_bias',
fig_name = 'figs_ntk/cifar10.png'
lg_tags = ['estim_sgd', 'optim_sgd', 'adam', 'kfac', 'estim_ntk', 'batch_size_', 'lr_', 'damping_']
ylim = [None]*20
# ylim = [None]*2 + [[80, 100], [80, 100], [1e-7, 1], None]
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 5
lg_replace = [('optim_sgd', 'SGD'), ('estim_sgd', 'SGD'), ('kfac', 'K-FAC'), ('SGD,K-FAC', 'K-FAC'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)

# %% [markdown]
# lr=0.2 is slightly better in val loss but the same in train loss

# %% [markdown]
# # Kfac bs 1024

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_ntk_bs1024_sgd/.*kfac']  # (?!.*scheduler)
tag_names = ['est_var', 'est_nvar', 'Tacc', 'Vacc', 'Tloss', 'Vloss']  # 'lr', 'gb_td', 'grad_bias',
fig_name = 'figs_ntk/cifar10.png'
lg_tags = ['estim_sgd', 'optim_sgd', 'adam', 'kfac', 'estim_ntk', 'batch_size_', 'lr_', 'damping_']
# ylim = [None]*20
ylim = [None]*2 + [[80, 100], [80, 100], [1e-5, 1e-3], None]
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 5
lg_replace = [('optim_sgd', 'SGD'), ('estim_sgd', 'SGD'), ('kfac', 'K-FAC'), ('SGD,K-FAC', 'K-FAC'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)

# %% [markdown]
# lr=0.1, eps=0.01 is best in train loss

# %% [markdown]
# # Resnet32 large and small batch

# %%
get_data_f = get_data_pth
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/u/faghri/dmom/code/runs/'
patterns = ['.*runs_cifar10_gvar_ntk_bs1024/.*lr_0.01.*damping_0.03|.*runs_cifar10_gvar_ntk_bs128/(00|01|.*lr_0.005.*damping_0.01)|.*runs_cifar10_gvar_ntk_bs1024_sgd/((?!.*kfac).*lr_0.2|.*kfac.*lr_0.1.*damping_0.01)']  # (?!.*scheduler)
tag_names = ['est_var', 'est_nvar', 'Tacc', 'Vacc', 'Tloss', 'Vloss']  # 'lr', 'gb_td', 'grad_bias',
fig_name = 'figs_ntk/cifar10.png'
lg_tags = ['estim_sgd', 'optim_sgd', 'adam', 'kfac', 'estim_ntk', 'batch_size_', 'lr_', 'damping_']
# ylim = [None]*20
ylim = [None]*2 + [[80, 100], [80, 100], [1e-7, 1], None]
# ylim = [[.2e-4, 1e-4], [0, 1.5e-7], [-1, 0.1], None, [98, 100], [98, 100], None, None]
# ylim = [[1e-4, 1e-1], [1e-2, 1e-1], [98, 100], [97,100], [0, 100], None, None, None, None, None, None, None, None, None, None, None, None]
sep_h = True
ncolor = 3
lg_replace = [('optim_sgd', 'SGD'), ('estim_sgd', 'SGD'), ('kfac', 'K-FAC'), ('SGD,K-FAC', 'K-FAC'), ('estim_ntk', 'NTK'), ('adamw', 'AdamW'), ('adam', 'Adam'), ('lr_', 'LR='), ('LR=0.001', 'LR=1e-3'), ('LR=0.0001', 'LR=1e-4'), ('LR=0.0005', 'LR=5e-4'), ('LR=0.0002', 'LR=2e-4'), ('batch_size_', 'bs='), ('optim_start_', 'Start='), ('damping_', '$\epsilon=$')]
data, run_names = plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace)
